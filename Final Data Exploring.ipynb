# %%
import pandas as pd

df = pd.read_csv('finalCombinedFeatures')

# %%
import matplotlib.pyplot as plt

jan12 = df[df['date']=='2021-01-12']

# %%
jan12_300 = jan12[:300]

# %%
plt.plot(jan12_300.time, jan12_300.MidPrice)
plt.plot(jan12_300.time, jan12_300.askBestPrice)

# %%
plt.plot(df.date.unique(),df.EMA10Days.unique() )
plt.plot(df.date.unique(),df.EMA16Days.unique() )
plt.plot(df.date.unique(),df.EMA22Days.unique() )

# %%
df.date.unique()
# Out:
# array(['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#        '2021-01-10', '2021-01-11', '2021-01-12', '2021-01-13',
#        '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20',
#        '2021-01-21', '2021-01-24', '2021-01-25', '2021-01-26',
#        '2021-01-27', '2021-02-02', '2021-02-03', '2021-02-07',
#        '2021-02-08', '2021-02-09', '2021-02-10', '2021-02-11',
#        '2021-02-14', '2021-02-15', '2021-02-16', '2021-02-17',
#        '2021-02-18', '2021-02-21', '2021-02-22', '2021-02-23',
#        '2021-02-24', '2021-02-25', '2021-03-01', '2021-03-02',
#        '2021-03-04', '2021-03-08', '2021-03-09', '2021-03-10',
#        '2021-04-29'], dtype=object)

# %%
dai = pd.read_csv('dailySummaryFinal')
dai.closingPrice
# Out:
# 0     220.0
# 1     212.0
# 2     216.0
# 3     206.0
# 4     211.0
#       ...
# 76    140.0
# 77    147.0
# 78    140.0
# 79    133.0
# 80    134.0
# Name: closingPrice, Length: 81, dtype: float64
