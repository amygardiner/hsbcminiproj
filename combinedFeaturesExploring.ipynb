# %%
import pandas as pd 

dailySummary = pd.read_csv('dailySummaryFinal')
dailySummary
# Out:
#     Unnamed: 0  closingPrice  highestPrice  lowestPrice  volumeTraded  \
# 0            2         220.0         238.0        179.0        118075
# 1            7         212.0         242.0        196.0        117591
# 2            1         216.0         242.0        186.0        118054
# 3            8         206.0         237.0        185.0        118730
# 4           10         211.0         233.0        184.0        118508
# ..         ...           ...           ...          ...           ...
# 76          68         140.0         145.0        109.0        118778
# 77          73         147.0         147.0        110.0        118181
# 78          79         140.0         147.0        111.0        118796
# 79          72         133.0         141.0        105.0        118770
# 80          64         134.0         136.0        104.0        118957
#
#     SMA10Days  SMA16Days   SMA22Days   EMA10Days   EMA16Days   EMA22Days  \
# ...

# %%
del dailySummary['Unnamed: 0']

# %%
dailySummary
# Out:
#     closingPrice  highestPrice  lowestPrice  volumeTraded  SMA10Days  \
# 0          220.0         238.0        179.0        118075        NaN
# 1          212.0         242.0        196.0        117591        NaN
# 2          216.0         242.0        186.0        118054        NaN
# 3          206.0         237.0        185.0        118730        NaN
# 4          211.0         233.0        184.0        118508        NaN
# ..           ...           ...          ...           ...        ...
# 76         140.0         145.0        109.0        118778      156.0
# 77         147.0         147.0        110.0        118181      155.1
# 78         140.0         147.0        111.0        118796      152.6
# 79         133.0         141.0        105.0        118770      147.7
# 80         134.0         136.0        104.0        118957      143.2
#
#     SMA16Days   SMA22Days   EMA10Days   EMA16Days   EMA22Days  \
# 0         NaN         NaN  220.000000  220.000000  220.000000
# ...

# %%
allCombined = pd.read_csv('combinedFeaturesv2.csv')

# %%
lOBFeatures = pd.read_csv('lOBFeatures',parse_dates=True, dayfirst=True)
lOBFeatures
# Out:
#          Unnamed: 0       time  Price  Quantity  MicroPrice  MidPrice  \
# 0                 0      4.176  186.0         2      200.40     222.0
# 1                 1      4.176  185.0         2      200.40     222.0
# 2                 2      5.056  187.0         1      204.00     221.0
# 3                 3      5.168  187.0         1      204.00     221.0
# 4                 4      5.168  185.0         2      204.00     221.0
# ...             ...        ...    ...       ...         ...       ...
# 2174737       52875  30592.992  207.0         1      203.57     205.0
# 2174738       52876  30596.736  207.0         1      205.33     206.0
# 2174739       52877  30596.736  207.0         1      205.33     206.0
# 2174740       52878  30599.680  237.0         1      246.57     270.5
# 2174741       52879  30599.680  237.0         1      246.57     270.5
#
#          QuotedSpread  bidAvg  bidIqr  bidBestPrice  ...  numberOfBids  \
# ...

# %%
lOBFeatures['date']=pd.to_datetime(lOBFeatures['date'], format='%d/%m/%Y')

# %%
dailySummary['date']=pd.to_datetime(dailySummary['date'])

# %%
lOBFeatures
# Out:
#          Unnamed: 0       time  Price  Quantity  MicroPrice  MidPrice  \
# 0                 0      4.176  186.0         2      200.40     222.0
# 1                 1      4.176  185.0         2      200.40     222.0
# 2                 2      5.056  187.0         1      204.00     221.0
# 3                 3      5.168  187.0         1      204.00     221.0
# 4                 4      5.168  185.0         2      204.00     221.0
# ...             ...        ...    ...       ...         ...       ...
# 2174737       52875  30592.992  207.0         1      203.57     205.0
# 2174738       52876  30596.736  207.0         1      205.33     206.0
# 2174739       52877  30596.736  207.0         1      205.33     206.0
# 2174740       52878  30599.680  237.0         1      246.57     270.5
# 2174741       52879  30599.680  237.0         1      246.57     270.5
#
#          QuotedSpread  bidAvg  bidIqr  bidBestPrice  ...  numberOfBids  \
# ...

# %%
merged = pd.merge(dailySummary,lOBFeatures, on='date', how='inner')

# %%
merged.columns
# Out:
# Index(['closingPrice', 'highestPrice', 'lowestPrice', 'volumeTraded',
#        'SMA10Days', 'SMA16Days', 'SMA22Days', 'EMA10Days', 'EMA16Days',
#        'EMA22Days', 'daysUntilWeekend', 'daysUntilMonthEnd', 'date', 'ind',
#        'Unnamed: 0', 'time', 'Price', 'Quantity', 'MicroPrice', 'MidPrice',
#        'QuotedSpread', 'bidAvg', 'bidIqr', 'bidBestPrice',
#        'bidQuantityAtBestPrice', 'bidQuantAvg', 'bidQuantIqr', 'numberOfBids',
#        'askAvg', 'askIqr', 'askBestPrice', 'askQuantityAtBestPrice',
#        'askQuantAvg', 'askQuantIqr', 'numberOfAsks', 'index'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.plot(merged.EMA10Days.unique())

# %%
merged.to_csv('finalCombinedFeatures')
