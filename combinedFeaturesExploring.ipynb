# %%
import datetime

import pandas as pd

dailySummary = pd.read_csv('/Users/brookegrantham/Documents/DSMP hm/dailySummaryFinal')
dailySummary
# Out:
#     Unnamed: 0  closingPrice  highestPrice  lowestPrice  volumeTraded  \
# 0            2         220.0         238.0        179.0        118075
# 1            7         212.0         242.0        196.0        117591
# 2            1         216.0         242.0        186.0        118054
# 3            8         206.0         237.0        185.0        118730
# 4           10         211.0         233.0        184.0        118508
# ..         ...           ...           ...          ...           ...
# 76          68         140.0         145.0        109.0        118778
# 77          73         147.0         147.0        110.0        118181
# 78          79         140.0         147.0        111.0        118796
# 79          72         133.0         141.0        105.0        118770
# 80          64         134.0         136.0        104.0        118957
#
#     SMA10Days  SMA16Days   SMA22Days   EMA10Days   EMA16Days   EMA22Days  \
# ...

# %%
del dailySummary['Unnamed: 0']

# %%
dailySummary
# Out:
#     closingPrice  highestPrice  lowestPrice  volumeTraded  SMA10Days  \
# 0          220.0         238.0        179.0        118075        NaN
# 1          212.0         242.0        196.0        117591        NaN
# 2          216.0         242.0        186.0        118054        NaN
# 3          206.0         237.0        185.0        118730        NaN
# 4          211.0         233.0        184.0        118508        NaN
# ..           ...           ...          ...           ...        ...
# 76         140.0         145.0        109.0        118778      156.0
# 77         147.0         147.0        110.0        118181      155.1
# 78         140.0         147.0        111.0        118796      152.6
# 79         133.0         141.0        105.0        118770      147.7
# 80         134.0         136.0        104.0        118957      143.2
#
#     SMA16Days   SMA22Days   EMA10Days   EMA16Days   EMA22Days  \
# 0         NaN         NaN  220.000000  220.000000  220.000000
# ...

# %%
from datetime import date
from matplotlib import dates as dates

# %%
for i in range(len(dailySummary)):
    dailySummary['date'][i]=dailySummary['date'][i].replace('-','/')
    dailySummary['date'][i]= dates.datestr2num(dailySummary['date'][i])
# Out:
# /var/folders/g4/q2c7q3553szgh172m493hl4r0000gn/T/ipykernel_88214/4028590409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dailySummary['date'][i]=dailySummary['date'][i].replace('-','/')
# /var/folders/g4/q2c7q3553szgh172m493hl4r0000gn/T/ipykernel_88214/4028590409.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dailySummary['date'][i]= dates.datestr2num(dailySummary['date'][i])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
ax = plt.subplot(2,1,1)
ax.plot(dailySummary.date, dailySummary.SMA10Days, label='10 Days')
ax.plot(dailySummary.date, dailySummary.SMA16Days, label='16 Days')
ax.plot(dailySummary.date, dailySummary.SMA22Days, label='22 Days')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.title('Simple Moving Average (SMA)')
plt.xticks(rotation=45)
ax.xaxis.set_major_formatter(dates.DateFormatter('%d/%m/%Y'))
ax = plt.subplot(2,1,2)
ax.plot(dailySummary.date, dailySummary.EMA10Days, label='10 Days')
ax.plot(dailySummary.date, dailySummary.EMA16Days, label='16 Days')
ax.plot(dailySummary.date, dailySummary.EMA22Days, label='22 Days')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.title('Exponential Moving Average (EMA)')
plt.xticks(rotation=45)
ax.xaxis.set_major_formatter(dates.DateFormatter('%d/%m/%Y'))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.5)

# %%
allCombined = pd.read_csv('/Users/brookegrantham/Documents/DSMP hm/finalCombinedFeatures')
allCombined
# Out:
#          Unnamed: 0.1  closingPrice  highestPrice  lowestPrice  volumeTraded  \
# 0                   0         220.0         238.0        179.0        118075
# 1                   1         220.0         238.0        179.0        118075
# 2                   2         220.0         238.0        179.0        118075
# 3                   3         220.0         238.0        179.0        118075
# 4                   4         220.0         238.0        179.0        118075
# ...               ...           ...           ...          ...           ...
# 2174737       2174737         134.0         136.0        104.0        118957
# 2174738       2174738         134.0         136.0        104.0        118957
# 2174739       2174739         134.0         136.0        104.0        118957
# 2174740       2174740         134.0         136.0        104.0        118957
# 2174741       2174741         134.0         136.0        104.0        118957
#
# ...

# %%
plt.plot(allCombined.time[1200:1400],allCombined.QuotedSpread[1200:1400], label='Quoted Spread')
plt.plot(allCombined.time[1200:1400],allCombined.MidPrice[1200:1400], label='Mid Price')
plt.legend()

# %%
plt.plot(allCombined.time[1200:1400], allCombined.numberOfAsks[1200:1400], label='# of bids')
plt.plot(allCombined.time[1200:1400], allCombined.numberOfBids[1200:1400], label='# of asks')
plt.plot(allCombined.time[1200:1400], allCombined.QuotedSpread[1200:1400], label='Quoted Spread')
plt.legend()

# %%
# merged.to_csv('finalCombinedFeatures')
